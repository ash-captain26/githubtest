# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("cp01.csv")

# %%
df
# Out:
#          id score_band  final_score  decision  crif_score      foir  \
# 0      5936       Gold           67  Declined         719   81.8351
# 1      5936       Gold           67  Declined         719   81.8351
# 2      5936   Platinum           82  Approved         719   44.8145
# 3      6078   Platinum           76  Approved         679   20.0000
# 4      6112   Platinum           77  Approved         708   20.5315
# ...     ...        ...          ...       ...         ...       ...
# 4633  18258       Gold           71  Declined         587  118.9017
# 4634  18270     Reject           46  Declined           0  460.0000
# 4635  18271       Gold           72  Declined         708  479.5293
# 4636  18273       Gold           73  Approved         654   67.6073
# 4637  18274       Gold           66  Declined         667  217.9106
#
#       total_expenses  final_turnover  calculated_emi  house_owned  \
# 0         23527.6000        143750.0       1527.6000         True
# ...

# %%
df1=pd.read_excel("cp02.xlsx",sheet_name="Main Sheet")

# %%
df1
# Out:
#              Customer Name         Office             LAN  LMS ID  Status  \
# 0             Narendra Rai  Jaipur_Branch  BLJAI000000018      18  Active
# 1          Shravan Ramavat  Mumbai_Branch  BLMUM000000029      29  Active
# 2         Viral Dilip Shah  Mumbai_Branch  BLMUM000000031      31  Active
# 3           Poonam Jaiswal  Jaipur_Branch  BLJAI000000047      47  Active
# 4             Rohit Sharma  Jaipur_Branch  BLJAI000000052      52  Active
# ...                    ...            ...             ...     ...     ...
# 6618          BHARAT SINGH   Delhi_Branch  BLDEL000009738    9738  Active
# 6619             RAJ KUMAR  Jaipur_Branch  BLJAI000009739    9739  Active
# 6620                 ANUJ    Delhi_Branch  BLDEL000009740    9740  Active
# 6621  SANJAYKUMAR RADADIYA  Mumbai_Branch  BLMUM000009741    9741  Active
# 6622           AMIT SAWANT  Mumbai_Branch  BLMUM000009742    9742  Active
#
#      Disbursement Date  Principal Disbursed  Principal Paid  \
# ...

# %%
left_join=pd.merge(df,df1,on="LAN",how="left")

# %%
left_join
# Out:
#          id score_band  final_score  decision  crif_score      foir  \
# 0      5936       Gold           67  Declined         719   81.8351
# 1      5936       Gold           67  Declined         719   81.8351
# 2      5936   Platinum           82  Approved         719   44.8145
# 3      6078   Platinum           76  Approved         679   20.0000
# 4      6112   Platinum           77  Approved         708   20.5315
# ...     ...        ...          ...       ...         ...       ...
# 4633  18258       Gold           71  Declined         587  118.9017
# 4634  18270     Reject           46  Declined           0  460.0000
# 4635  18271       Gold           72  Declined         708  479.5293
# 4636  18273       Gold           73  Approved         654   67.6073
# 4637  18274       Gold           66  Declined         667  217.9106
#
#       total_expenses  final_turnover  calculated_emi  house_owned  ...  Bkt  \
# ...

# %%
import matplotlib.pyplot as plt

# %%
left_join.plot.scatter(x='foir',y='LAN')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-9efcd28b6a7d> in <module>()
# ----> 1 left_join.plot.scatter(x='foir',y='LAN')
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in scatter(self, x, y, s, c, **kwargs)
#    1442             ...                       colormap='viridis')
#    1443         """
# -> 1444         return self(kind="scatter", x=x, y=y, s=s, c=c, **kwargs)
#    1445
#    1446     def hexbin(self, x, y, C=None, reduce_C_function=None, gridsize=None, **kwargs):
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     736         if kind in self._dataframe_kinds:
#     737             if isinstance(data, ABCDataFrame):
# --> 738                 return plot_backend.plot(data, x=x, y=y, kind=kind, **kwargs)
#     739             else:
#     740                 raise ValueError(
#
# ...
